# %% [markdown]
# https://archive.ics.uci.edu/ml/datasets/Student+Performance

# %% [markdown]
# Stduents performance database

# %% [markdown]
# Presentacion Diego Molina

# %% [markdown]
# Se habla sobre el desempeño de los albumons de dos escuelas dependiendo de diferentes variables y datos

# %% [markdown]
# ### Variables
# ### 1 school - student's school - binary
# ### 2 sex - student's sex - binary
# ### 3 age - student's age - numeric
# ### 4 address - student's home address type - binary
# ### 5 famsize - family size - binary
# ### 6 Pstatus - parent's cohabitation status - binary
# ### 7 Medu - mother's education - numeric
# ### 8 Fedu - father's education - numeric
# ### 9 Mjob - mother's job - nominal
# ### 10 Fjob - father´s job - nominal
# ### 11 reason - reason to choose this school - nominal
# ### 12 guardian - student's guardian - nominal
# ### 13 traveltime - home to school travel time - numeric
# ### 14 studytime - weekly study time - numeric
# ### 15 failures - number of past class failures - numeric
# ### 16 schoolsup - extra educational support - binary
# ### 17 famsup - family educational support - binary
# ### 18 paid - extra paid classes within the course subject - binary
# ### 19 activities - extra-curricular activities - binary
# ### 20 nursery - attended nursery school - binary
# ### 21 higher - wants to take higher education - binary
# ### 22 internet - Internet access at home - binary
# ### 23 romantic - with a romantic relationship - binary
# ### 24 famrel - quality of family relationships - numeric
# ### 25 freetime - free time after school - numeric
# ### 26 goout - going out with friends - numeric
# ### 27 Dalc - workday alcohol consumption - numeric
# ### 28 Walc - weekend alcohol consumption - numeric
# ### 29 health - current health status - numeric
# ### 30 absences - number of school absences - numeric

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %ls database.xlsx
# Out:
# database.xlsx

# %%
pip install xlrd
# Out:
# ...
#      |████████████████████████████████| 96 kB 3.1 MB/s
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install statsmodels
# Out:
# ...
#      |████████████████████████████████| 9.8 MB 4.6 MB/s
# ...
#      |████████████████████████████████| 233 kB 65.4 MB/s
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install openpyxl
# Out:
# ...
#      |████████████████████████████████| 242 kB 4.9 MB/s
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install matplotlib
# Out:
# ...
#      |████████████████████████████████| 11.2 MB 4.9 MB/s
# ...
#      |████████████████████████████████| 15.7 MB 64.3 MB/s
# ...
#      |████████████████████████████████| 898 kB 49.9 MB/s
# ...
#      |████████████████████████████████| 1.1 MB 63.3 MB/s
# ...
#      |████████████████████████████████| 4.3 MB 63.0 MB/s
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install seaborn
# Out:
# ...
#      |████████████████████████████████| 292 kB 4.8 MB/s
# ...
#      |████████████████████████████████| 38.1 MB 51.5 MB/s
# ...
#      |████████████████████████████████| 11.3 MB 78.6 MB/s
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
df=pd.read_excel('database.xlsx',
                 engine='openpyxl',
                 sheet_name='student-mat',
                )
df
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...

# %% [markdown]
# Cuales son los primeros tres alumnos, o los que estan primeros en la lista? ( se muestran las primeras tres filas)

# %%
df=pd.read_excel('database.xlsx',
                 engine='openpyxl',
                 sheet_name='student-mat',
                )
df.head(3)
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob     Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home  teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home    other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home    other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences G1 G2  G3
# 0      4        3      4     1     1      3        6  5  6   6
# 1      5        3      3     1     1      3        4  5  5   6
# 2      4        3      2     2     3      3       10  7  8  10
#
# [3 rows x 33 columns]

# %% [markdown]
# ### Aqui podemos ver que las primeras tres fialas o alumnos estudian en GP y son mujeres y que sus mamas se quedan en casa

# %% [markdown]
# Cuales son los ultimos tres alumnos? (se muestran las ultimas tres filas)

# %%
df.tail(3)
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob     Fjob  \
# 392     MS   M   21       R     GT3       T     1     1     other    other
# 393     MS   M   18       R     LE3       T     3     2  services    other
# 394     MS   M   19       U     LE3       T     1     1     other  at_home
#
#      ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 392  ...      5        5      3     3     3      3        3  10   8   7
# 393  ...      4        4      1     3     4      5        0  11  12  10
# 394  ...      3        2      3     3     3      5        5   8   9   9
#
# [3 rows x 33 columns]

# %% [markdown]
# ¿Como estan distribuidas las edades de los alumnos?

# %%
hist_plot=df['age'].plot(kind='hist')

# %% [markdown]
# Cual es el promedio de la edad de los alumnos?

# %%
df['age'].mean()
# Out:
# 16.696202531645568

# %% [markdown]
# Podemos ver que la edad promedio es de 16.69

# %% [markdown]
# En que rango estan distribuidos las calficiaciones de G2 y G3 y comaparalas?

# %%
sns.boxplot(data=df.loc[:,['G3', 'G2'
                          ]])
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Podemos ver que en G2 nos da un outlier  en 0 ya que no es un dato regular. POdemos ver que la distribucion esta alrededor de la misma media y son simetricas.

# %% [markdown]
# Existe correlacion entre la edad y las calificaciones de G1?

# %%
sns.lmplot(x = 'G1',
           y = 'age',
           data = df,
           fit_reg =False,
          )
plt.title('Scatter plot of age vs G1')
# Out:
# Text(0.5, 1.0, 'Scatter plot of age vs G1')

# %% [markdown]
# Aqui podemos ver que no hay relacion entre las calificaciones y la edad ya que los de menor edad tambien han sacado buenas calificaciones.

# %% [markdown]
# Cual es la correlacion entre las variables, esta relaciona dos variables linealmente?

# %%
df.corr()
# Out:
#                  age      Medu      Fedu  traveltime  studytime  failures  \
# age         1.000000 -0.163658 -0.163438    0.070641  -0.004140  0.243665
# Medu       -0.163658  1.000000  0.623455   -0.171639   0.064944 -0.236680
# Fedu       -0.163438  0.623455  1.000000   -0.158194  -0.009175 -0.250408
# traveltime  0.070641 -0.171639 -0.158194    1.000000  -0.100909  0.092239
# studytime  -0.004140  0.064944 -0.009175   -0.100909   1.000000 -0.173563
# failures    0.243665 -0.236680 -0.250408    0.092239  -0.173563  1.000000
# famrel      0.053940 -0.003914 -0.001370   -0.016808   0.039731 -0.044337
# freetime    0.016434  0.030891 -0.012846   -0.017025  -0.143198  0.091987
# goout       0.126964  0.064094  0.043105    0.028540  -0.063904  0.124561
# Dalc        0.131125  0.019834  0.002386    0.138325  -0.196019  0.136047
# Walc        0.117276 -0.047123 -0.012631    0.134116  -0.253785  0.141962
# health     -0.062187 -0.046878  0.014742    0.007501  -0.075616  0.065827
# ...

# %% [markdown]
# Podemos ver por ejemplo que entre la variable age y las failures si hay una correlacion fuerte.

# %%
import statsmodels.api as sm

# %% [markdown]
# Cual es el valor de la regresion entre G1 y traveltime? (R cuadrada)

# %%
model=sm.OLS.from_formula('G1~traveltime', data=df)
result=model.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                     G1   R-squared:                       0.009
# Model:                            OLS   Adj. R-squared:                  0.006
# Method:                 Least Squares   F-statistic:                     3.432
# Date:                Fri, 18 Mar 2022   Prob (F-statistic):             0.0647
# Time:                        00:06:09   Log-Likelihood:                -1032.2
# No. Observations:                 395   AIC:                             2068.
# Df Residuals:                     393   BIC:                             2076.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     11.5500      0.384     30.073      0.000      10.795      12.305
# ...

# %% [markdown]
# Podemos ver que el valor de la R cuadrada es de 0.009
